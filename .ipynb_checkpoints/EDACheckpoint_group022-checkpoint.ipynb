# %% [markdown]
# # COGS 108 - EDA Checkpoint

# %% [markdown]
# # Names
#
# - Gijung Lapeyrouse
# - Matthew Gustafson
# - Ariel Bastomski
# - Andy Chan
# - Alexander Dimopoulos

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# How does one's risk of cardiovascular disease change depending on their lifestyle choices? Are certain regions of the United States more prone to these risks than others, and why might that be?

# %% [markdown]
# # Setup

# %%
# Import seaborn and apply its plotting styles
import seaborn as sns
sns.set(style="white", font_scale=1.5)

# import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt
# set plotting size parameter
plt.rcParams['figure.figsize'] = (17, 7)

# make sure pandas & numpy are imported
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

#improve resolution
#comment this line if erroring on your machine/screen
# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
# Read the csv file for Dataset #1
data1 = pd.read_csv('cardiovascular_diseases_dv3.csv')

# Cleaning steps for Dataset #2
# Read the csv file for Dataset #2
data = pd.read_csv('500_Cities__Coronary_heart_disease_among_adults_aged___18_years.csv')

# Include only cities and age-adjusted prevalence rates for observations
data = data[(data['GeographicLevel'] == 'City') & (data['DataValueTypeID'] == 'AgeAdjPrv')]

# Include only the necessary columns for analysis
data_trimmed = data[['Year', 'StateAbbr', 'StateDesc', 'CityName', 'Measure', 'Data_Value_Unit', 'Data_Value_Type', 
                     'Data_Value', 'Low_Confidence_Limit', 'High_Confidence_Limit', 'PopulationCount']].reset_index()
# Out:
#    AGE  GENDER  HEIGHT  WEIGHT  AP_HIGH  AP_LOW  CHOLESTEROL  GLUCOSE  SMOKE  \
# 0   50       2     168      62      110      80            1        1      0
# 1   55       1     156      85      140      90            3        1      0
# 2   52       1     165      64      130      70            3        1      0
# 3   48       2     169      82      150     100            1        1      0
# 4   48       1     156      56      100      60            1        1      0
#
#    ALCOHOL  PHYSICAL_ACTIVITY  CARDIO_DISEASE
# 0        0                  1               0
# 1        0                  1               1
# 2        0                  0               1
# 3        0                  1               1
# 4        0                  0               0

# %%
# Display sample from Dataset #1
data1.head()
# Out:
#    AGE  GENDER  HEIGHT  WEIGHT  AP_HIGH  AP_LOW  CHOLESTEROL  GLUCOSE  SMOKE  \
# 0   50       2     168      62      110      80            1        1      0
# 1   55       1     156      85      140      90            3        1      0
# 2   52       1     165      64      130      70            3        1      0
# 3   48       2     169      82      150     100            1        1      0
# 4   48       1     156      56      100      60            1        1      0
#
#    ALCOHOL  PHYSICAL_ACTIVITY  CARDIO_DISEASE
# 0        0                  1               0
# 1        0                  1               1
# 2        0                  0               1
# 3        0                  1               1
# 4        0                  0               0

# %%
# Display sample from Dataset #2
data_trimmed.head()
# Out:
#    index  Year StateAbbr   StateDesc     CityName  \
# 0      0  2017        CA  California      Hayward
# 1      4  2017        CA  California   Bellflower
# 2      9  2017        FL     Florida   Cape Coral
# 3     16  2017        KS      Kansas  Kansas City
# 4     28  2017        OH        Ohio        Parma
#
#                                              Measure Data_Value_Unit  \
# 0  Coronary heart disease among adults aged >=18 ...               %
# 1  Coronary heart disease among adults aged >=18 ...               %
# 2  Coronary heart disease among adults aged >=18 ...               %
# 3  Coronary heart disease among adults aged >=18 ...               %
# 4  Coronary heart disease among adults aged >=18 ...               %
#
#            Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 0  Age-adjusted prevalence         4.8                   4.7
# 1  Age-adjusted prevalence         5.3                   5.2
# 2  Age-adjusted prevalence         6.3                   6.2
# 3  Age-adjusted prevalence         7.1                   7.0
# 4  Age-adjusted prevalence         6.0                   5.8
#
#    High_Confidence_Limit  PopulationCount
# 0                    4.8           144186
# 1                    5.4            76616
# 2                    6.4           154305
# 3                    7.1           145786
# 4                    6.1            81601

# %% [markdown]
# # Data Analysis & Results (EDA)

# %% [markdown]
# Carry out EDA on your dataset(s); Describe in this section

# %% [markdown]
# # 1.) Question
# # There are several associations we would like to explore in our datasets:
# # a) Can we distinguish any connections between state and having a higher rate of coronary heart disease?
# # b)

# %%
# 2.) First lets get a general idea of the format of our data

df = data_trimmed

print('Shape: ')
print(df.shape)
print(f'\n')

print('Types:')
print(df.dtypes)
print(f'\n')

print('Value Counts: ')
print(df['StateAbbr'].value_counts())
print(f'\n')

print('Hearth value above 8:')
print(df[df['Data_Value'] > 8])
print(f'\n')

df.describe()
# Out:
# Shape:
# (500, 12)
#
#
# Types:
# index                      int64
# Year                       int64
# StateAbbr                 object
# StateDesc                 object
# CityName                  object
# Measure                   object
# Data_Value_Unit           object
# Data_Value_Type           object
# Data_Value               float64
# Low_Confidence_Limit     float64
# High_Confidence_Limit    float64
# PopulationCount            int64
# dtype: object
#
#
# Value Counts:
# CA    121
# TX     47
# FL     33
# IL     18
# MI     16
# NC     14
# CO     14
# WA     14
# MA     13
# AZ     12
# GA     11
# VA     11
# IN     11
# NJ      9
# UT      9
# OH      9
# NY      9
# OR      8
# CT      8
# MO      8
# WI      7
# MN      7
# PA      7
# KS      6
# AL      6
# IA      6
# LA      6
# OK      6
# TN      6
# SC      5
# AR      5
# NV      5
# NM      4
# RI      4
# ID      3
# NH      2
# MS      2
# NE      2
# SD      2
# MT      2
# KY      2
# WV      1
# WY      1
# ME      1
# DC      1
# DE      1
# VT      1
# ND      1
# HI      1
# MD      1
# AK      1
# Name: StateAbbr, dtype: int64
#
#
# Hearth value above 8:
#      index  Year StateAbbr     StateDesc    CityName  \
# 241  12247  2017        IN       Indiana        Gary
# 283  14722  2017        MI      Michigan     Detroit
# 303  15422  2017        MI      Michigan       Flint
# 333  16910  2017        NJ    New Jersey      Camden
# 366  21039  2017        OH          Ohio   Cleveland
# 368  21229  2017        OH          Ohio      Canton
# 371  21496  2017        OH          Ohio  Youngstown
# 376  21786  2017        OH          Ohio      Dayton
# 400  23321  2017        PA  Pennsylvania     Reading
#
#                                                Measure Data_Value_Unit  \
# 241  Coronary heart disease among adults aged >=18 ...               %
# 283  Coronary heart disease among adults aged >=18 ...               %
# 303  Coronary heart disease among adults aged >=18 ...               %
# 333  Coronary heart disease among adults aged >=18 ...               %
# 366  Coronary heart disease among adults aged >=18 ...               %
# 368  Coronary heart disease among adults aged >=18 ...               %
# 371  Coronary heart disease among adults aged >=18 ...               %
# 376  Coronary heart disease among adults aged >=18 ...               %
# 400  Coronary heart disease among adults aged >=18 ...               %
#
#              Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 241  Age-adjusted prevalence         8.3                   8.2
# 283  Age-adjusted prevalence         8.8                   8.7
# 303  Age-adjusted prevalence         8.8                   8.7
# 333  Age-adjusted prevalence         8.2                   8.1
# 366  Age-adjusted prevalence         8.5                   8.4
# 368  Age-adjusted prevalence         8.2                   8.0
# 371  Age-adjusted prevalence         8.7                   8.6
# 376  Age-adjusted prevalence         8.4                   8.3
# 400  Age-adjusted prevalence         8.6                   8.5
#
#      High_Confidence_Limit  PopulationCount
# 241                    8.4            80294
# 283                    8.8           713777
# 303                    8.9           102434
# 333                    8.4            77344
# 366                    8.5           396815
# 368                    8.3            73007
# 371                    8.9            66982
# 376                    8.5           141527
# 400                    8.7            88082
#               index    Year  Data_Value  Low_Confidence_Limit  \
# count    500.000000   500.0  500.000000            500.000000
# mean   13582.928000  2017.0    5.676000              5.573000
# std     8768.474475     0.0    1.016174              1.009619
# min        0.000000  2017.0    3.500000              3.400000
# 25%     6550.000000  2017.0    4.900000              4.800000
# 50%    12525.000000  2017.0    5.700000              5.600000
# 75%    21656.500000  2017.0    6.400000              6.300000
# max    28998.000000  2017.0    8.800000              8.700000
#
#        High_Confidence_Limit  PopulationCount
# count             500.000000     5.000000e+02
# mean                5.782000     2.060416e+05
# std                 1.018937     4.574810e+05
# min                 3.600000     4.241700e+04
# 25%                 5.000000     8.159000e+04
# 50%                 5.800000     1.061060e+05
# 75%                 6.500000     1.811278e+05
# max                 8.900000     8.175133e+06

# %% [markdown]
# # From this analysis we can see that a majority of the patients are from CA, TX, and FL. We also see that that the average data value for coronary heart disease is about 5.7, with the lowest at 3.5 and a maximum of 8.8.

# %%
# 3.) Visualize statistics about these variables
ax = sns.barplot(x="StateAbbr", y="Data_Value", data=df, order=df.StateAbbr.value_counts().iloc[:5].index)
ax.set(xlabel='State', ylabel='Average % Coronary Heart Disease', title='Average percentage of coronary heart disease per state across all cities')
# Out:
# [Text(0, 0.5, 'Average % Coronary Heart Disease'),
#  Text(0.5, 0, 'State'),
#  Text(0.5, 1.0, 'Average percentage of coronary heart disease per state across all cities')]

# %% [markdown]
# # Based on the results above, it looks like MI, FL, and TX have the highest average rate of coronary heart disease in the US.
